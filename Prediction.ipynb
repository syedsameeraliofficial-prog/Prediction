# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %%
file=pd.read_csv('homeprices2.csv')
file
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
bed_median=file.bedrooms.median()
bed_median
# Out:
# np.float64(4.0)

# %%
file.bedrooms=file.bedrooms.fillna(bed_median)
file
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
sns.pairplot(file)

# %%
reg = linear_model.LinearRegression()
reg
# Out:
# LinearRegression()

# %%
# Y = mx + b 
# price (Dependant variable ) = (m1x1 + m2x2 + m3x3) + b

# %%
reg.fit(file.drop('price' , axis='columns') , file.price)
#      (         x                           , y        )
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
file
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg.predict([[3800, 4,20 ]])
# Out:
# C:\Users\hp 840\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([676081.44338461])

# %%
reg.intercept_
# Out:
# np.float64(221323.0018654043)

# %%
y=  ((112.06244194*3800)+(23388.88007794*4)+(-3231.71790863*20))+221323.0018654043
y
# Out:
# 676081.4433765644
